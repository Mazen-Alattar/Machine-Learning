# %%
import pandas as pd

# %%
#to read a specific number pf rows
df = pd.read_csv("nyc_weather.csv",  nrows=2)
df
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  Events  \
# 0               10             8                0           5     NaN
# 1               10             7                0           3     NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
#read data
df=pd.read_csv('nyc_weather.csv')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#show the table (columns and rows)
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.head(10)
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   1/1/2016           38        23        52                 30.03
# 1   1/2/2016           36        18        46                 30.02
# 2   1/3/2016           40        21        47                 29.86
# 3   1/4/2016           25         9        44                 30.05
# 4   1/5/2016           20        -3        41                 30.57
# 5   1/6/2016           33         4        35                 30.50
# 6   1/7/2016           39        11        33                 30.28
# 7   1/8/2016           39        29        64                 30.20
# 8   1/9/2016           44        38        77                 30.16
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# ...

# %%
#show the last five rows 
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.tail(10)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 21                9           NaN            0.01           3      Snow
# ...

# %%
df.shape # rows, columns = df.shape
# Out:
# (31, 11)

# %%
newdf = df[2:5] #rows
newdf
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
newdf = df.iloc[2:5, :-1] #except last column
newdf
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN

# %%
#show all information about your data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.8+ KB

# %%
#number of unique value in each column 
df.nunique()
# Out:
# EST                     31
# Temperature             22
# DewPoint                21
# Humidity                23
# Sea Level PressureIn    26
# VisibilityMiles          5
# WindSpeedMPH            12
# PrecipitationIn          7
# CloudCover               9
# Events                   3
# WindDirDegrees          28
# dtype: int64

# %%
#describe each coulmn 
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
#show the counts of each unique value in the column 
df['Temperature'].value_counts()
# Out:
# Temperature
# 26    3
# 36    3
# 25    2
# 33    2
# 39    2
# 34    2
# 43    2
# 38    1
# 22    1
# 37    1
# 41    1
# 28    1
# 31    1
# 32    1
# 30    1
# 47    1
# 35    1
# 50    1
# 44    1
# 20    1
# 40    1
# 46    1
# Name: count, dtype: int64

# %%
df["Sea Level PressureIn"]
# Out:
# 0     30.03
# 1     30.02
# 2     29.86
# 3     30.05
# 4     30.57
# 5     30.50
# 6     30.28
# 7     30.20
# 8     30.16
# 9     29.59
# 10    29.92
# 11    29.85
# 12    29.94
# 13    29.95
# 14    29.82
# 15    29.52
# 16    29.78
# 17    29.83
# 18    30.03
# 19    30.13
# 20    30.15
# 21    30.21
# 22    29.77
# 23    29.92
# 24    30.25
# 25    30.03
# 26    30.03
# 27    29.90
# 28    29.58
# 29    30.01
# 30    29.90
# Name: Sea Level PressureIn, dtype: float64

# %%
df["Sea Level PressureIn"].max()
# Out:
# 30.57

# %%
df["Sea Level PressureIn"].min()
# Out:
# 29.52

# %%
#change data tyype 
df["Sea Level PressureIn"] = df["Sea Level PressureIn"].astype("float32")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
x =df.columns.to_list()
print(x)
type(x)
# Out:
# ['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn', 'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover', 'Events', 'WindDirDegrees']
# list

# %%
for i in df.Temperature:
    if (i > 30):
        print(i)
# Out:
# 38
# 36
# 40
# 33
# 39
# 39
# 44
# 50
# 33
# 35
# 43
# 47
# 36
# 32
# 31
# 34
# 43
# 41
# 37
# 36
# 34
# 46

# %%
df.loc[0][0] #location
# Out:
# '1/1/2016'

# %%
df.columns[0]
# Out:
# 'EST'

# %%
df['EST'][0:5]
# Out:
# 0    1/1/2016
# 1    1/2/2016
# 2    1/3/2016
# 3    1/4/2016
# 4    1/5/2016
# Name: EST, dtype: object

# %%
len(df[df.Temperature==30])  # condition in pandas


#counter = 0          # you can use too The normal way
#for i in df.Temperature:
#    if (i == 30):
#        counter+=1
#counter
# Out:
# 1

# %%
df [ df.Events == "Rain"   ]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 15  1/16/2016           47        37        70             29.520000
# 26  1/27/2016           41        22        45             30.030001
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
df["EST"][df.Events == "Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
print(df.DewPoint.dtype)
# Out:
# int64

# %%
len(df['EST'][ df['Events']!= 'Rain'])
# Out:
# 27

# %%
print(f"you have : {len(df.columns)} columns" )
# Out:
# you have : 11 columns

# %%
df.fillna("?") # fill not a number values
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
newdf = df.fillna(0)
newdf
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df.fillna(0, inplace=True)   # to save changes in data

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df.rename(columns={'EST':'Day'},inplace=True) # to change name of columns
df
# Out:
#           Day  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df.set_index("Day", inplace=True)    #set index
df
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Day
# 1/1/2016            38        23        52             30.030001
# 1/2/2016            36        18        46             30.020000
# 1/3/2016            40        21        47             29.860001
# 1/4/2016            25         9        44             30.049999
# 1/5/2016            20        -3        41             30.570000
# 1/6/2016            33         4        35             30.500000
# 1/7/2016            39        11        33             30.280001
# 1/8/2016            39        29        64             30.200001
# 1/9/2016            44        38        77             30.160000
# 1/10/2016           50        46        71             29.590000
# 1/11/2016           33         8        37             29.920000
# 1/12/2016           35        15        53             29.850000
# 1/13/2016           26         4        42             29.940001
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#           Day  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...
